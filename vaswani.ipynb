# %% [markdown]
# # PyTerrier ColBERT Demo Notebook - Vaswani
#
# This notebook demonstrates use of [PyTerrier plugin for ColBERT](https://github.com/terrierteam/pyterrier_colbert) for dense passage retrieval.
#
# [ColBERT](https://github.com/stanford-futuredata/ColBERT/tree/v0.2) is a fast and accurate retrieval model, enabling scalable BERT-based search over large text collections in tens of milliseconds. ColBERT relies on fine-grained contextual late interaction: it encodes each passage into a matrix of token-level embeddings. Then at search time, it embeds every query into another matrix of token-level embeddings and efficiently finds passages that contextually match the query using scalable vector-similarity (MaxSim) operators.
#
#
# [ColBERT](https://arxiv.org/abs/2004.12832) is built on top of [BERT](https://arxiv.org/abs/1810.04805). ColBERT surpasses the quality of single-vector representation models, while scaling efficiently to large corpora.
#
# The corpus used in this demo is the [Vaswani NPL corpus](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/), a corpus of 11,429 scientific abstract, with corresponding queries and relevance assessments.

# %% [markdown]
# ## Installation
#
# We need to install [PyTerrier](https://github.com/terrier-org/pyterrier).

# %%
# !pip install python-terrier
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-terrier
#   Downloading python-terrier-0.9.1.tar.gz (102 kB)
#      |████████████████████████████████| 102 kB 5.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from python-terrier) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from python-terrier) (1.3.5)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from python-terrier) (4.64.1)
# Collecting pyjnius>=1.4.2
#   Downloading pyjnius-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 27.9 MB/s
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 6.5 MB/s
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from python-terrier) (1.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from python-terrier) (1.2.0)
# Collecting nptyping==1.4.4
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.8/dist-packages (from python-terrier) (9.0.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.4-py3-none-any.whl (311 kB)
#      |████████████████████████████████| 311 kB 69.0 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from python-terrier) (0.12.2)
# Collecting ir_measures>=0.3.1
#   Downloading ir_measures-0.3.1.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 4.3 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from python-terrier) (0.3.6)
# Collecting pytrec_eval_terrier>=0.5.3
#   Downloading pytrec_eval_terrier-0.5.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (286 kB)
#      |████████████████████████████████| 286 kB 67.5 MB/s
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.4 MB/s
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting lz4>=3.1.1
#   Downloading lz4-4.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 44.0 MB/s
# Collecting ijson>=3.1.3
#   Downloading ijson-3.1.4-cp38-cp38-manylinux2010_x86_64.whl (133 kB)
#      |████████████████████████████████| 133 kB 73.1 MB/s
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.1.tar.gz (5.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.6.3)
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.9-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (293 kB)
#      |████████████████████████████████| 293 kB 74.4 MB/s
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp38-cp38-manylinux2010_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.5 MB/s
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from ir_datasets>=0.3.2->python-terrier) (6.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.8/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.1)
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from pyjnius>=1.4.2->python-terrier) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier) (3.0.4)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.8/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.8/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->python-terrier) (2022.6)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels->python-terrier) (0.5.3)
# Building wheels for collected packages: python-terrier, ir-measures, cwl-eval, cbor, unlzw3, warc3-wet-clueweb09, chest, sklearn, wget
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.9.1-py3-none-any.whl size=110765 sha256=26ab84df0bf35b5ffa0aec9bcd4748b3317b0f8ef6c9ec597b0c9739f981d133
#   Stored in directory: /root/.cache/pip/wheels/07/09/d7/57e3b3ba472d9ccf28f1a7ffc179db1a4e7c16be497c324ceb
#   Building wheel for ir-measures (setup.py) ... done
#   Created wheel for ir-measures: filename=ir_measures-0.3.1-py3-none-any.whl size=60192 sha256=a7f166507c497947414a1b2aa70f58fa8d9812eee99f96bfa0548ca599aac477
#   Stored in directory: /root/.cache/pip/wheels/e0/62/25/77a51a011fc5c0a771372e08914c2d7451b3e76114a1067358
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38085 sha256=1aed9bccb4ef7bdab9679cd02f24758e58f449c5881082ad0d0f34cb008522e1
#   Stored in directory: /root/.cache/pip/wheels/6f/20/44/7bd8b3e175eb9d1343f1668f7d57e36f1a9fcb74ef7cd269ed
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp38-cp38-linux_x86_64.whl size=52537 sha256=a4f62f03b9bc8fcff54a9eafa2a5ea33b9305a2004ed50ed8234541694d8c139
#   Stored in directory: /root/.cache/pip/wheels/31/3a/8a/9d1a5e6f83f620826578089812b8ac236b86eaf4fbc3b36384
#   Building wheel for unlzw3 (PEP 517) ... done
#   Created wheel for unlzw3: filename=unlzw3-0.2.1-py3-none-any.whl size=6083 sha256=7a84e9f84ed3847dd87383f146119664c2c117ede6c87e6f7e0450e521de65f2
#   Stored in directory: /root/.cache/pip/wheels/16/12/7c/662a9b523c77aec10cc0ec1e7c97628aabd3f8ae202184e015
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18920 sha256=113db4a0e8c336b59e5315ec9d88399d142d9cd5dc8b5397774aebabb221b055
#   Stored in directory: /root/.cache/pip/wheels/2f/81/96/219c1a4ebbcb766834ccef089c56481b761c26d8ed235e21dc
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7633 sha256=fc06d626ce5c1b4d537b543560f588fcdab7c3415860997a7bbc8ca8b345bd69
#   Stored in directory: /root/.cache/pip/wheels/a3/10/0c/3c77925ea9d4deccf5e0a06a27a2c4cea4464bb57d68015eba
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=5f6060e944c596bf7b48e6ea77d75490129a50344f025b35fdfd5386547ccb1d
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=d8a1880989bc316a86aa2eaaf2ec26515c63229fe2d083ebc1b2196cda71709a
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built python-terrier ir-measures cwl-eval cbor unlzw3 warc3-wet-clueweb09 chest sklearn wget
# Installing collected packages: cbor, zlib-state, warc3-wet-clueweb09, warc3-wet, unlzw3, typish, trec-car-tools, pytrec-eval-terrier, pyautocorpus, multiset, lz4, ijson, cwl-eval, wget, sklearn, pyjnius, nptyping, matchpy, ir-measures, ir-datasets, deprecated, chest, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.13 ijson-3.1.4 ir-datasets-0.5.4 ir-measures-0.3.1 lz4-4.0.2 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.9 pyjnius-1.4.2 python-terrier-0.9.1 pytrec-eval-terrier-0.5.5 sklearn-0.0.post1 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.1 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5

# %% [markdown]
# This installs the [PyTerrier plugin for ColBERT](https://github.com/terrierteam/pyterrier_colbert). It supplies an indexer and a retrieval transformer.

# %%
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_colbert.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/terrierteam/pyterrier_colbert.git
#   Cloning https://github.com/terrierteam/pyterrier_colbert.git to /tmp/pip-req-build-8z4e5o9t
#   Running command git clone -q https://github.com/terrierteam/pyterrier_colbert.git /tmp/pip-req-build-8z4e5o9t
# Collecting ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT
#   Cloning https://github.com/cmacdonald/ColBERT.git (to revision v0.2) to /tmp/pip-install-mple5szk/colbert_3bfad04156c94600bff61ff69c4ae4b6
#   Running command git clone -q https://github.com/cmacdonald/ColBERT.git /tmp/pip-install-mple5szk/colbert_3bfad04156c94600bff61ff69c4ae4b6
#   Running command git checkout -b v0.2 --track origin/v0.2
#   Switched to a new branch 'v0.2'
#   Branch 'v0.2' set up to track remote branch 'v0.2' from 'origin'.
# Requirement already satisfied: python-terrier>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from pyterrier-colbert==0.0.1) (0.9.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from pyterrier-colbert==0.0.1) (1.3.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from pyterrier-colbert==0.0.1) (1.13.0+cu116)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from pyterrier-colbert==0.0.1) (1.0.2)
# Collecting transformers<5,>=3.0.2
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 5.1 MB/s
# Collecting ujson
#   Downloading ujson-5.6.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.7 MB/s
# Collecting mlflow
#   Downloading mlflow-2.0.1-py3-none-any.whl (16.5 MB)
#      |████████████████████████████████| 16.5 MB 37.7 MB/s
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (4.64.1)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.3.1)
# Requirement already satisfied: chest in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.3)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.5.4)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.4.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.7.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.0.post1)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.5.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.21.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.2.0)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.4.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.23.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.2.13)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.5.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (9.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.3.6)
# Requirement already satisfied: wget in /usr/local/lib/python3.8/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.2)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from nptyping==1.4.4->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (6.0)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.6)
# Requirement already satisfied: lz4>=3.1.1 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (4.0.2)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.1.5)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.1.9)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.1.4)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.1)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.3)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (4.9.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (4.6.3)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.8/dist-packages (from ir-measures>=0.3.1->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.0.12)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from pyjnius>=1.4.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2022.9.24)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (4.4.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 75.6 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 66.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.0.9)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.0.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.8/dist-packages (from chest->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.8/dist-packages (from deprecated->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.14.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.0.1)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from matchpy->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.1.1)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.4.44)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.5.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.4)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (7.1.2)
# Collecting alembic<2
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 73.7 MB/s
# Requirement already satisfied: pyarrow<11,>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (9.0.0)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 75.0 MB/s
# Collecting shap<1,>=0.40
#   Downloading shap-0.41.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (575 kB)
#      |████████████████████████████████| 575 kB 71.7 MB/s
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.4.3)
# Requirement already satisfied: pytz<2023 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2022.6)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.4.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (4.13.0)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.2.2)
# Collecting gunicorn<21
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.4 MB/s
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.1.4)
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 62.8 MB/s
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.19.6)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 589 kB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic<2->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (5.10.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.7 MB/s
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.8/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.8.10)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.0-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 75.6 MB/s
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 79.0 MB/s
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.6 MB/s
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.8/dist-packages (from Flask<3->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from Flask<3->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.1.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.8/dist-packages (from gunicorn<21->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.11.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->pyterrier-colbert==0.0.1) (3.1.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from shap<1,>=0.40->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.56.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy<2,>=1.4.0->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.0.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->shap<1,>=0.40->mlflow->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.39.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.5.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.15.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.51.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.4.8)
# Building wheels for collected packages: pyterrier-colbert, ColBERT, databricks-cli
#   Building wheel for pyterrier-colbert (setup.py) ... done
#   Created wheel for pyterrier-colbert: filename=pyterrier_colbert-0.0.1-py3-none-any.whl size=26132 sha256=11c393c97e03420e305e9e0ec3bfaf11153adcf30eee4b82d146ba924ef023b1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-89qidrz8/wheels/fe/00/05/671917ae5aff7952b5da3abc2971cc302aba8038e43381de95
#   Building wheel for ColBERT (setup.py) ... done
#   Created wheel for ColBERT: filename=ColBERT-0.2.0-py3-none-any.whl size=48638 sha256=083b02ff551f2bbe3eedc9e22b33a0dba4d485e4a431322ebca7b39d50f8973f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-89qidrz8/wheels/a3/25/89/4a78e5c94ec1dfd826f4320ddda521cea960d9c48f90e4191b
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142894 sha256=dcaebad59efa2a14d5a3dbfd0019c64061a2ac6925367089df3fe8377d14021e
#   Stored in directory: /root/.cache/pip/wheels/48/7c/6e/4bf2c1748c7ecf994ca951591de81674ed6bf633e1e337d873
# Successfully built pyterrier-colbert ColBERT databricks-cli
# Installing collected packages: smmap, websocket-client, slicer, pyjwt, Mako, gitdb, tokenizers, shap, querystring-parser, huggingface-hub, gunicorn, gitpython, docker, databricks-cli, alembic, ujson, transformers, mlflow, ColBERT, pyterrier-colbert
# Successfully installed ColBERT-0.2.0 Mako-1.2.4 alembic-1.8.1 databricks-cli-0.17.4 docker-5.0.3 gitdb-4.0.10 gitpython-3.1.29 gunicorn-20.1.0 huggingface-hub-0.11.1 mlflow-2.0.1 pyjwt-2.6.0 pyterrier-colbert-0.0.1 querystring-parser-1.2.4 shap-0.41.0 slicer-0.0.7 smmap-5.0.0 tokenizers-0.13.2 transformers-4.25.1 ujson-5.6.0 websocket-client-1.4.2

# %% [markdown]
# This installs [FAISS](https://github.com/facebookresearch/faiss), a library for efficient similarity search and clustering of dense vectors.

# %%
import sys

COLAB='google.colab' in sys.modules

try:
  import faiss
  faiss.get_num_gpus()
except:
  if COLAB:
    print('Installing faiss-gpu from pip ')
    # !pip install faiss-gpu==1.6.3
  else:
    print('Installing faiss-gpu via Conda')
    # !conda install -c pytorch faiss-gpu

import faiss
assert faiss.get_num_gpus() > 0
# Out:
# Installing faiss-gpu from pip
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss-gpu==1.6.3
#   Downloading faiss_gpu-1.6.3-cp38-cp38-manylinux2010_x86_64.whl (35.5 MB)
#      |████████████████████████████████| 35.5 MB 1.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from faiss-gpu==1.6.3) (1.21.6)
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.6.3

# %% [markdown]
# # Setup
#
# Lets get [PyTerrier](https://github.com/terrier-org/pyterrier) started. This will download the latest version of the [Terrier](http://terrier.org) IR platform.

# %%
import pyterrier as pt
pt.init()
# Out:
# terrier-assemblies 5.7 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.7 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.9.1 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %% [markdown]
# This is the ColBERT checkpoint generated by Craig Macdonald. and used in our TREC 2020 Participation. It will be downloaded first time it is used. Downloading time varies.

# %%
checkpoint="http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip"

# %% [markdown]
# # Indexing
#
# This indexes the [Vaswani dataset](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/). Indexing takes about 3 minutes using a Colab GPU.

# %%
# !rm -rf /content/colbertindex

import pyterrier_colbert.indexing

indexer = pyterrier_colbert.indexing.ColBERTIndexer(checkpoint, "/content", "colbertindex", chunksize=3)
indexer.index(pt.get_dataset("irds:vaswani").get_corpus_iter())
# Out:
# vaswani documents:   0%|          | 0/11429 [00:00<?, ?it/s]
# [Dec 10, 16:28:31] [0] 		 #> Local args.bsize = 128
# [Dec 10, 16:28:31] [0] 		 #> args.index_root = /content
# [Dec 10, 16:28:31] [0] 		 #> self.possible_subset_sizes = [69905]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing ColBERT: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing ColBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ColBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ColBERT were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['linear.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Dec 10, 16:29:00] #> Loading model checkpoint.
# [Dec 10, 16:29:00] #> Loading checkpoint http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip
# Downloading: "http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip" to /root/.cache/torch/hub/checkpoints/colbert.dnn.zip
#   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/torch/hub.py:651: UserWarning: Falling back to the old format < 1.6. This support will be deprecated in favor of default zipfile format introduced in 1.6. Please redo torch.save() to save it in the new zipfile format.
#   warnings.warn('Falling back to the old format < 1.6. This support will be '
# [Dec 10, 16:30:54] #> checkpoint['epoch'] = 0
# [Dec 10, 16:30:54] #> checkpoint['batch'] = 44500
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [Dec 10, 16:30:56] #> Note: Output directory /content already exists
#
#
#
#
# [Dec 10, 16:30:56] #> Creating directory /content/colbertindex
# [INFO] [starting] http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz
#
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 0.0%| 0.00/2.13M [00:00<?, ?B/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 2.3%| 49.2k/2.13M [00:00<00:08, 244kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 4.6%| 98.3k/2.13M [00:00<00:06, 322kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 7.7%| 164k/2.13M [00:00<00:04, 400kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 15.8%| 336k/2.13M [00:00<00:02, 653kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 31.6%| 672k/2.13M [00:00<00:01, 1.08MB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 64.0%| 1.36M/2.13M [00:00<00:00, 1.88MB/s]
# [INFO] [finished] http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: [00:00] [2.13MB] [2.88MB/s]
#
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: [00:00] [2.13MB] [2.86MB/s]
# [Dec 10, 16:32:50] [0] 		 #> Completed batch #0 (starting at passage #0) 		Passages/min: 6.0k (overall),  6.1k (this encoding),  15218.0M (this saving)
# [Dec 10, 16:32:51] [0] 		 [NOTE] Done with local share.
# [Dec 10, 16:32:51] [0] 		 #> Joining saver thread.
# [Dec 10, 16:32:51] [0] 		 #> Saved batch #0 to /content/colbertindex/0.pt 		 Saving Throughput = 2.3M passages per minute.
#
# #> num_embeddings = 581496
# [Dec 10, 16:32:51] #> Starting..
# [Dec 10, 16:32:51] #> Processing slice #1 of 1 (range 0..1).
# [Dec 10, 16:32:51] #> Will write to /content/colbertindex/ivfpq.100.faiss.
# [Dec 10, 16:32:51] #> Loading /content/colbertindex/0.sample ...
# #> Sample has shape (29074, 128)
# [Dec 10, 16:32:51] Preparing resources for 1 GPUs.
# [Dec 10, 16:32:51] #> Training with the vectors...
# [Dec 10, 16:32:51] #> Training now (using 1 GPUs)...
# 108.56665992736816
# 27.515798807144165
# 0.0008912086486816406
# [Dec 10, 16:35:07] Done training!
#
# [Dec 10, 16:35:07] #> Indexing the vectors...
# [Dec 10, 16:35:07] #> Loading ('/content/colbertindex/0.pt', None, None) (from queue)...
# [Dec 10, 16:35:07] #> Processing a sub_collection with shape (581496, 128)
# [Dec 10, 16:35:07] Add data with shape (581496, 128) (offset = 0)..
# 524288/581496 (3.034 s)   Flush indexes to CPU
# add(.) time: 3.158 s 		--		 index.ntotal = 581496
# [Dec 10, 16:35:10] Done indexing!
# [Dec 10, 16:35:10] Writing index to /content/colbertindex/ivfpq.100.faiss ...
# [Dec 10, 16:35:10]
#
# Done! All complete (for slice #1 of 1)!
# #> Faiss encoding complete
# #> Indexing complete, Time elapsed 399.78 seconds

# %% [markdown]
# The indexing procedure generates the document embeddings index and a [FAISS](https://github.com/facebookresearch/faiss) index, together with some additional files.

# %%
# !ls -ltrh /content/colbertindex
# Out:
# total 168M
# -rw-r--r-- 1 root root 142M Dec 10 16:32 0.pt
# -rw-r--r-- 1 root root 4.5M Dec 10 16:32 0.tokenids
# -rw-r--r-- 1 root root 7.1M Dec 10 16:32 0.sample
# -rw-r--r-- 1 root root  35K Dec 10 16:32 doclens.0.json
# -rw-r--r-- 1 root root  24K Dec 10 16:32 docnos.pkl.gz
# -rw-r--r-- 1 root root  14M Dec 10 16:35 ivfpq.100.faiss

# %% [markdown]
# # Retrieval
#
# Now that indexing has completed, we can load in the index and the checkpoint model (which we will need for encoding queries). Index loading can take some times, as the [FAISS](https://github.com/facebookresearch/faiss) index needs to be loaded in main memory, as well as the document embeddings index.
#
# Since we indexed a collection from scratch and the data structures are already loaded in main memory, we reuse the data structures for retrieval.
#
# In the case the indexing was done offline, the following ColBERT factory can be used:
#
# ```python
# pyterrier_colbert_factory = pyterrier_colbert.ranking.ColBERTFactory(checkpoint, "/content", "colbertindex")
# ```

# %%
pyterrier_colbert_factory = indexer.ranking_factory()

colbert_e2e = pyterrier_colbert_factory.end_to_end()
# Out:
# [Dec 10, 16:37:38] #> Loading the FAISS index from /content/colbertindex/ivfpq.100.faiss ..
# [Dec 10, 16:37:38] #> Building the emb2pid mapping..
# [Dec 10, 16:37:38] len(self.emb2pid) = 581496
# Loading reranking index, memtype=mem
# Loading index shards to memory:   0%|          | 0/1 [00:00<?, ?shard/s]

# %% [markdown]
# Here we can ask [PyTerrier](https://github.com/terrier-org/pyterrier) to search the [ColBERT](https://github.com/stanford-futuredata/ColBERT/tree/v0.2) index for `'chemical reactions'`, returning the top 10 scored documents.

# %%
(colbert_e2e % 10).search("chemical reactions")
# Out:
#      qid               query  docid  \
# 1861   1  chemical reactions   4911
# 2388   1  chemical reactions   7048
# 2262   1  chemical reactions   6479
# 532    1  chemical reactions   9373
# 2216   1  chemical reactions   6278
# 1103   1  chemical reactions   2420
# 1708   1  chemical reactions   4292
# 1147   1  chemical reactions  10702
# 1981   1  chemical reactions   5303
# 1419   1  chemical reactions   3100
#
#                                              query_toks  \
# 1861  [tensor(101), tensor(1), tensor(5072), tensor(...
# 2388  [tensor(101), tensor(1), tensor(5072), tensor(...
# 2262  [tensor(101), tensor(1), tensor(5072), tensor(...
# 532   [tensor(101), tensor(1), tensor(5072), tensor(...
# 2216  [tensor(101), tensor(1), tensor(5072), tensor(...
# 1103  [tensor(101), tensor(1), tensor(5072), tensor(...
# 1708  [tensor(101), tensor(1), tensor(5072), tensor(...
# 1147  [tensor(101), tensor(1), tensor(5072), tensor(...
# 1981  [tensor(101), tensor(1), tensor(5072), tensor(...
# 1419  [tensor(101), tensor(1), tensor(5072), tensor(...
#
#                                              query_embs      score  docno  \
# 1861  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  19.824471   4912
# 2388  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  19.053652   7049
# 2262  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  18.034084   6480
# 532   [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  17.139666   9374
# 2216  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  16.793507   6279
# 1103  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  16.426735   2421
# 1708  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  16.193594   4293
# 1147  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  16.152369  10703
# 1981  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  16.009520   5304
# 1419  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  15.882051   3101
#
#       rank
# 1861     0
# 2388     1
# 2262     2
# 532      3
# 2216     4
# 1103     5
# 1708     6
# 1147     7
# 1981     8
# 1419     9

# %% [markdown]
# # Run an experiment
#
# Lets prepare an experiment. Firstly, lets create in a BM25 baseline transformer.

# %%
dataset = pt.get_dataset("vaswani")

bm25 = pt.BatchRetrieve(dataset.get_index(), wmodel="BM25")
# Out:
# Downloading vaswani index to /root/.pyterrier/corpora/vaswani/index
# HBox(children=(FloatProgress(value=0.0, description='data.direct.bf', max=334927.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='data.document.fsarrayfile', max=194293.0, style=ProgressS…
# HBox(children=(FloatProgress(value=0.0, description='data.inverted.bf', max=308600.0, style=ProgressStyle(desc…
# HBox(children=(FloatProgress(value=0.0, description='data.lexicon.fsomapfile', max=667016.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=0.0, description='data.lexicon.fsomaphash', max=777.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='data.lexicon.fsomapid', max=31024.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='data.meta.idx', max=91432.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='data.meta.zdata', max=171754.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='data.properties', max=882.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='data.meta-0.fsomapfile', max=742885.0, style=ProgressStyl…

# %% [markdown]
# Finally, lets evaluate our performance. We also load in an BM25 index for the same corpus for comparison reasons. We limit our experiments to just 50 queries.

# %%
pt.Experiment(
    [bm25, colbert_e2e],
    dataset.get_topics().head(50),
    dataset.get_qrels(),
    eval_metrics=["map", "recip_rank", "mrt"],
    names = ["BM25", "ColBERT"]
)
# Out:
# Downloading vaswani topics to /root/.pyterrier/corpora/vaswani/query-text.trec
# HBox(children=(FloatProgress(value=0.0, description='query-text.trec', max=3121.0, style=ProgressStyle(descrip…
# Downloading vaswani qrels to /root/.pyterrier/corpora/vaswani/qrels
# HBox(children=(FloatProgress(value=0.0, description='qrels', max=6793.0, style=ProgressStyle(description_width…
#       name       map  recip_rank         mrt
# 0     BM25  0.338941    0.808238   44.980815
# 1  ColBERT  0.333021    0.762643  780.633069
